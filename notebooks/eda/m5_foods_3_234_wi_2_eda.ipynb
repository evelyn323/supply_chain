# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Raw Data

# %%
calendar_df = pd.read_csv("../data/raw/calendar.csv", parse_dates=["date"])
calendar_df["d"] = [f"d_{i}" for i in range(1, len(calendar_df) + 1)]
sales_df = pd.read_csv("../data/raw/sales_train_validation.csv")
wk_prices_df = pd.read_csv("../data/raw/sell_prices.csv")

# %%
sku_df = sales_df[(sales_df["store_id"] == "WI_2") & (sales_df["item_id"] == "FOODS_3_234")]
sku_df = pd.melt(sku_df,
                 id_vars=["item_id", "dept_id", "cat_id", "store_id", "state_id"],
                 value_vars=[c for c in sku_df.columns if c.startswith("d_")],
                 var_name="d",
                 value_name="demand")

sku_df = sku_df.merge(
    calendar_df,
    on="d",
    how="left",
)
sku_df = sku_df.sort_values("date").reset_index(drop=True)

# %%
price_df = wk_prices_df[
    (wk_prices_df["store_id"] == "WI_2") &
    (wk_prices_df["item_id"] == "FOODS_3_234")
].copy()

sku_df = sku_df.merge(
    price_df,
    on=["store_id", "item_id", "wm_yr_wk"],
    how="left"
)

# %%
sku_df.head()
# Out:
#        item_id  dept_id cat_id store_id state_id    d  demand       date  \
# 0  FOODS_3_234  FOODS_3  FOODS     WI_2       WI  d_1      58 2011-01-29
# 1  FOODS_3_234  FOODS_3  FOODS     WI_2       WI  d_2      45 2011-01-30
# 2  FOODS_3_234  FOODS_3  FOODS     WI_2       WI  d_3      41 2011-01-31
# 3  FOODS_3_234  FOODS_3  FOODS     WI_2       WI  d_4     109 2011-02-01
# 4  FOODS_3_234  FOODS_3  FOODS     WI_2       WI  d_5      18 2011-02-02
#
#    wm_yr_wk    weekday  ...  month  year  event_name_1 event_type_1  \
# 0     11101   Saturday  ...      1  2011           NaN          NaN
# 1     11101     Sunday  ...      1  2011           NaN          NaN
# 2     11101     Monday  ...      1  2011           NaN          NaN
# 3     11101    Tuesday  ...      2  2011           NaN          NaN
# 4     11101  Wednesday  ...      2  2011           NaN          NaN
#
#   event_name_2 event_type_2 snap_CA  snap_TX  snap_WI  sell_price
# 0          NaN          NaN       0        0        0         0.2
# 1          NaN          NaN       0        0        0         0.2
# 2          NaN          NaN       0        0        0         0.2
# 3          NaN          NaN       1        1        0         0.2
# 4          NaN          NaN       1        0        1         0.2
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Exploration

# %%
sku_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1913 entries, 0 to 1912
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   item_id       1913 non-null   str
#  1   dept_id       1913 non-null   str
#  2   cat_id        1913 non-null   str
#  3   store_id      1913 non-null   str
#  4   state_id      1913 non-null   str
#  5   d             1913 non-null   str
#  6   demand        1913 non-null   int64
#  7   date          1913 non-null   datetime64[us]
#  8   wm_yr_wk      1913 non-null   int64
#  9   weekday       1913 non-null   str
#  10  wday          1913 non-null   int64
#  11  month         1913 non-null   int64
#  12  year          1913 non-null   int64
#  13  event_name_1  154 non-null    str
#  14  event_type_1  154 non-null    str
#  15  event_name_2  4 non-null      str
#  16  event_type_2  4 non-null      str
#  17  snap_CA       1913 non-null   int64
#  18  snap_TX       1913 non-null   int64
#  19  snap_WI       1913 non-null   int64
#  20  sell_price    1913 non-null   float64
# dtypes: datetime64[us](1), float64(1), int64(8), str(11)
# memory usage: 405.4 KB

# %%
sku_df.describe()
# Out:
#             demand                 date      wm_yr_wk         wday  \
# count  1913.000000                 1913   1913.000000  1913.000000
# mean     26.159435  2013-09-11 00:00:00  11339.191323     3.997386
# min       0.000000  2011-01-29 00:00:00  11101.000000     1.000000
# 25%       0.000000  2012-05-21 00:00:00  11217.000000     2.000000
# 50%       9.000000  2013-09-11 00:00:00  11333.000000     4.000000
# 75%      41.000000  2015-01-02 00:00:00  11448.000000     6.000000
# max     229.000000  2016-04-24 00:00:00  11613.000000     7.000000
# std      36.557632                  NaN    150.413499     2.001175
#
#              month         year      snap_CA      snap_TX      snap_WI  \
# count  1913.000000  1913.000000  1913.000000  1913.000000  1913.000000
# mean      6.357554  2013.209096     0.329326     0.329326     0.329326
# min       1.000000  2011.000000     0.000000     0.000000     0.000000
# 25%       3.000000  2012.000000     0.000000     0.000000     0.000000
# 50%       6.000000  2013.000000     0.000000     0.000000     0.000000
# 75%       9.000000  2015.000000     1.000000     1.000000     1.000000
# max      12.000000  2016.000000     1.000000     1.000000     1.000000
# std       3.459678     1.532487     0.470091     0.470091     0.470091
#
#         sell_price
# count  1913.000000
# mean      0.201333
# min       0.200000
# 25%       0.200000
# 50%       0.200000
# 75%       0.200000
# max       0.250000
# std       0.008056

# %%
plt.figure(figsize=(12, 4))
plt.plot(sku_df["date"], sku_df["demand"], linewidth=1)
plt.title("Daily Demand for FOODS_3_234 at WI_2")
plt.xlabel("Date")
plt.ylabel("Units Sold")
plt.tight_layout()
plt.show()
